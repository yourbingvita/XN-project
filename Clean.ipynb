# %%
import numpy as np
import pandas as pd

# %%
epidu = pd.read_csv("C:\\Users\\dell\\Desktop\\Machine learning\\Project\\Hemorrhage Segmentation Project\\Results_Epidural Hemorrhage Detection_2020-11-16_21.31.26.148.csv")
Intra = pd.read_csv("C:\\Users\\dell\\Desktop\\Machine learning\\Project\\Hemorrhage Segmentation Project\\Results_Intraparenchymal Hemorrhage Detection_2020-11-16_21.39.31.268.csv")
Multiple = pd.read_csv("C:\\Users\\dell\\Desktop\\Machine learning\\Project\\Hemorrhage Segmentation Project\\Results_Multiple Hemorrhage Detection_2020-11-16_21.36.24.018.csv")
Subara = pd.read_csv("C:\\Users\\dell\\Desktop\\Machine learning\\Project\\Hemorrhage Segmentation Project\\Results_Subarachnoid Hemorrhage Detection_2020-11-16_21.36.18.668.csv")
Subdu1 = pd.read_csv("C:\\Users\\dell\\Desktop\\Machine learning\\Project\\Hemorrhage Segmentation Project\\Results_Subdural Hemorrhage Detection_2020-11-16_21.35.48.040.csv")
Subdu2 = pd.read_csv("C:\\Users\\dell\\Desktop\\Machine learning\\Project\\Hemorrhage Segmentation Project\\Results_Subdural Hemorrhage Detection_2020-11-16_21.37.19.745.csv")

# %%
wrong_w=['[]','[[],[]]','[[]]','[[], []]']
for i in wrong_w:
    #print(type(i))
    epidu=epidu.replace(to_replace= i, value=np.nan)
    Intra=Intra.replace(to_replace= i, value=np.nan)
    Multiple=Multiple.replace(to_replace= i, value=np.nan)
    Subara=Subara.replace(to_replace= i, value=np.nan)
    Subdu1=Subdu1.replace(to_replace= i, value=np.nan)
    Subdu2=Subdu2.replace(to_replace= i, value=np.nan)

epidu
#epil=epidu.replace(to_replace= '[]', value=np.nan)
#epio=epil.replace(to_replace= '[[],[]]', value=np.nan)
#epiu=epio.replace(to_replace= '[[]]', value=np.nan)
#epi=epiu.replace(to_replace= '[[], []]', value=np.nan)
# Out:
#      Case ID            Origin                                         URL  \
# 0    1196514  ID_004c4b319.jpg  https://go.centaurlabs.com/problem/1196514
# 1    1196682  ID_0237b835f.jpg  https://go.centaurlabs.com/problem/1196682
# 2    1196477  ID_02e2d273d.jpg  https://go.centaurlabs.com/problem/1196477
# 3    1196612  ID_02f37ce84.jpg  https://go.centaurlabs.com/problem/1196612
# 4    1196612  ID_02f37ce84.jpg  https://go.centaurlabs.com/problem/1196612
# ..       ...               ...                                         ...
# 605  1196614  ID_879afbc77.jpg  https://go.centaurlabs.com/problem/1196614
# 606  1196600  ID_af76460ee.jpg  https://go.centaurlabs.com/problem/1196600
# 607  1196767  ID_d6d369eaa.jpg  https://go.centaurlabs.com/problem/1196767
# 608  1196539  ID_d9bfa60ed.jpg  https://go.centaurlabs.com/problem/1196539
# 609  1196955  ID_fa2874be0.jpg  https://go.centaurlabs.com/problem/1196955
#
# ...

# %%
row_indexs=epidu[(epidu['Correct Label'].isnull())&(epidu['Majority Label'].isnull())].index
epi=epidu.drop(row_indexs)
#print(row_indexs)
#print(epi1[['Majority Label']])

# %%
ind= epi.index.to_list()
ind1=epi[epi['Majority Label'].isnull()]['Correct Label'].index.tolist()
#print(ind1)

# %%
epi['label']=''
for i in ind:
    if i in ind1:
       epi['label'][i]= epi['Correct Label'][i]
    else:
       epi['label'][i]= epi['Majority Label'][i]
# Out:
# C:\Users\dell\AppData\Local\Temp/ipykernel_23440/536915744.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   epi['label'][i]= epi['Majority Label'][i]
# C:\Users\dell\AppData\Local\Temp/ipykernel_23440/536915744.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   epi['label'][i]= epi['Correct Label'][i]

# %%
epi['label']
# Out:
# 0      [{"x": 0.537109375, "y": 0.89453125}, {"x": 0....
# 1      [{"x": 0.654296875, "y": 0.724609375}, {"x": 0...
# 2      [{"x": 0.46484375, "y": 0.357421875}, {"x": 0....
# 3      [{"x": 0.431640625, "y": 0.607421875}, {"x": 0...
# 4      [{"x": 0.353515625, "y": 0.59765625}, {"x": 0....
#                              ...
# 589    [[{'x': 0.541015625, 'y': 0.8125}, {'x': 0.541...
# 590    [[{'x': 0.220703125, 'y': 0.451171875}, {'x': ...
# 602    [[{'x': 0.48046875, 'y': 0.8828125}, {'x': 0.4...
# 608    [[{'x': 0.443359375, 'y': 0.810546875}, {'x': ...
# 609    [[{'x': 0.37890625, 'y': 0.318359375}, {'x': 0...
# Name: label, Length: 582, dtype: object
